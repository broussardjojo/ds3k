# %%
#imports
import sys
import pandas as pd
import pathlib
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import spotipy.util as util
import pprint
import json
import api_setup
from sklearn.preprocessing import OneHotEncoder

# %%
CWD = pathlib.Path.cwd()
REPO_ROOT = CWD.parent.parent.parent
DATA_DIR = REPO_ROOT / "data"
APP = 'spotify'
NAME = 'nick'
SUBDIRS = 'my_spotify_data/MyData/'
USER_DATA_DIR = DATA_DIR / APP / NAME / SUBDIRS

# API Keys
sys.path.append(REPO_ROOT)
from api_setup import parse_api_kvs
# Understanding the spotipy API and making sure it's installed correctly
env_vars = api_setup.parse_api_kvs(REPO_ROOT / "api-keys")
spotify = spotipy.Spotify(client_credentials_manager=SpotifyOAuth(**env_vars))

# %%
def addFeatures(uri):
    audioFeatures = spotify.audio_features(uri)
    audioFeatures = pd.DataFrame(audioFeatures)
    audioFeatures = audioFeatures.drop(columns = ['type','id','uri','track_href','analysis_url','mode',
                                                  'duration_ms','time_signature'])
    return audioFeatures.iloc[0]

# %%
addFeatures('4rKEmhNA19JezqVsSQS4yo')
# Out:
# danceability          0.7380
# energy                0.9540
# key                   1.0000
# loudness             -2.1460
# speechiness           0.0356
# acousticness          0.0692
# instrumentalness      0.0000
# liveness              0.2220
# valence               0.7420
# tempo               102.0150
# Name: 0, dtype: float64

# %%
def combineMasterFeatures(masterTable):
    master = pd.read_csv(masterTable)
    #master = master.head(10) #remove this line later
    master = master.drop(['Unnamed: 0'], axis = 1) #drop extra index
    master['uri'] = master['uri'].str.replace('spotify:track:','')
    audioFeaturesDF = pd.DataFrame()
    masterFeatures = pd.concat([master, master.apply(lambda x: addFeatures(x['uri']), axis = 1)], axis = 1)
    masterFeatures = masterFeatures.drop(columns=['track','uri'])
    return masterFeatures

# %%
masterFeatures = combineMasterFeatures('masterTable.csv')
masterFeatures.head(10)
# Out:
#                artist nick_history jojo_history rich_history  danceability  \
# 0          LOONA/yyxy          NaN         True          NaN         0.738
# 1         Danny Brown          NaN         True          NaN         0.690
# 2               Latto          NaN         True          NaN         0.790
# 3           MIMIDEATH          NaN         True          NaN         0.828
# 4          Rico Nasty          NaN         True          NaN         0.936
# 5              DaBaby         True         True          NaN         0.768
# 6      Otoboke Beaver          NaN         True          NaN         0.321
# 7           Flo Milli          NaN         True          NaN         0.782
# 8  Tyler, The Creator          NaN         True          NaN         0.443
# 9               Lorde          NaN         True          NaN         0.733
#
#    energy   key  loudness  speechiness  acousticness  instrumentalness  \
# 0   0.954   1.0    -2.146       0.0356       0.06920          0.000000
# 1   0.600   8.0    -7.331       0.2490       0.18700          0.000000
# 2   0.614   9.0    -6.958       0.0991       0.06060          0.000000
# 3   0.764   2.0    -7.361       0.1040       0.17000          0.309000
# 4   0.523   1.0    -6.390       0.2690       0.00365          0.000000
# 5   0.652   1.0    -2.708       0.3070       0.11300          0.000000
# 6   0.973   9.0    -1.191       0.1540       0.00751          0.684000
# 7   0.844  10.0    -4.142       0.2300       0.10700          0.000001
# 8   0.576   1.0    -8.695       0.2010       0.07090          0.019700
# 9   0.620   1.0   -10.525       0.0750       0.60600          0.305000
#
#    liveness  valence    tempo
# 0     0.222    0.742  102.015
# 1     0.694    0.761  160.080
# 2     0.239    0.630  145.907
# 3     0.237    0.289  110.987
# 4     0.105    0.278  130.014
# 5     0.107    0.777  154.187
# 6     0.086    0.574  132.201
# 7     0.295    0.760   77.435
# 8     0.410    0.127  151.835
# 9     0.117    0.247  111.039

# %%
#encode artists
enc = OneHotEncoder(sparse = False, handle_unknown='ignore')
encodeArtists = enc.fit_transform(masterFeatures[['artist']])
#create column containing encoded artists
masterFeatures['labelsArtists'] = encodeArtists
#remove categorical artist column
masterFeaturesEncode = masterFeatures.drop(columns = ['artist'])
masterFeaturesEncode.head(10)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'labelsArtists'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\pandas\core\frame.py:4138, in DataFrame._set_item_mgr(self, key, value)
#    4137 try:
# -> 4138     loc = self._info_axis.get_loc(key)
#    4139 except KeyError:
#    4140     # This item wasn't present, just insert at end
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key, method, tolerance)
#    3804 except KeyError as err:
# -> 3805     raise KeyError(key) from err
#    3806 except TypeError:
#    3807     # If we have a listlike key, _check_indexing_error will raise
#    3808     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3809     #  the TypeError.
#
# KeyError: 'labelsArtists'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In [46], line 5
#       3 encodeArtists = enc.fit_transform(masterFeatures[['artist']])
#       4 #create column containing encoded artists
# ----> 5 masterFeatures['labelsArtists'] = encodeArtists
#       6 #remove categorical artist column
#       7 masterFeaturesEncode = masterFeatures.drop(columns = ['artist'])
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\pandas\core\frame.py:3977, in DataFrame.__setitem__(self, key, value)
#    3974     self._setitem_array([key], value)
#    3975 else:
#    3976     # set column
# -> 3977     self._set_item(key, value)
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\pandas\core\frame.py:4184, in DataFrame._set_item(self, key, value)
#    4181         if isinstance(existing_piece, DataFrame):
#    4182             value = np.tile(value, (len(existing_piece.columns), 1)).T
# -> 4184 self._set_item_mgr(key, value)
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\pandas\core\frame.py:4141, in DataFrame._set_item_mgr(self, key, value)
#    4138     loc = self._info_axis.get_loc(key)
#    4139 except KeyError:
#    4140     # This item wasn't present, just insert at end
# -> 4141     self._mgr.insert(len(self._info_axis), key, value)
#    4142 else:
#    4143     self._iset_item_mgr(loc, value)
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\pandas\core\internals\managers.py:1388, in BlockManager.insert(self, loc, item, value)
#    1386     value = value.T
#    1387     if len(value) > 1:
# -> 1388         raise ValueError(
#    1389             f"Expected a 1D array, got an array with shape {value.T.shape}"
#    1390         )
#    1391 else:
#    1392     value = ensure_block_shape(value, ndim=self.ndim)
#
# ValueError: Expected a 1D array, got an array with shape (1542, 694)

# %%
def cleanHistory(df):
    return None
