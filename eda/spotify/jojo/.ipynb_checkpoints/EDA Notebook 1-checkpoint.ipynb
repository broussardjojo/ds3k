# %%
# Imports
import sys
import pandas as pd
import pathlib
import spotipy
from spotipy.oauth2 import SpotifyOAuth

import api_setup

CWD = pathlib.Path.cwd()
REPO_ROOT = CWD.parent.parent.parent
DATA_DIR = REPO_ROOT / "data"
APP = 'spotify'
NAME = 'jojo'
SUBDIRS = 'my_spotify_data/MyData/'
USER_DATA_DIR = DATA_DIR / APP / NAME / SUBDIRS

# API Keys
sys.path.append(REPO_ROOT)
from api_setup import parse_api_kvs

# %%
# Understanding StreamingHistory
streaming_history_0 = pd.read_json(USER_DATA_DIR / "StreamingHistory0.json")
streaming_history_0
# Out:
#                endTime       artistName                        trackName  \
# 0     2021-10-13 21:16       U.S. Girls                           L-Over
# 1     2021-10-14 00:55  Indigo De Souza         What Are We Gonna Do Now
# 2     2021-10-14 00:55            Yelle                           Ba$$in
# 3     2021-10-14 00:55    Amy Winehouse                         Addicted
# 4     2021-10-14 00:55        Baby Keem                        APOLOGIZE
# ...                ...              ...                              ...
# 9995  2022-02-19 06:01     The Internet          Girl (feat. KAYTRANADA)
# 9996  2022-02-19 06:04       KAYTRANADA                    What You Need
# 9997  2022-02-19 06:07       KAYTRANADA  $payforhaiti (feat. Mach-Hommy)
# 9998  2022-02-19 06:11       KAYTRANADA                    Hilarity Duff
# 9999  2022-02-19 06:13       KAYTRANADA   Gray Area (feat. Mick Jenkins)
#
#       msPlayed
# 0        90543
# 1         1405
# 2         3828
# 3         1317
# 4         1301
# ...        ...
# 9995    415613
# 9996    183786
# 9997    183773
# 9998    257463
# 9999    139653
#
# [10000 rows x 4 columns]

# %%
# Understanding the spotipy API and making sure it's installed correctly

env_vars = api_setup.parse_api_kvs(REPO_ROOT / "api-keys")

birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
spotify = spotipy.Spotify(client_credentials_manager=SpotifyOAuth(**env_vars))

results = spotify.artist_albums(birdy_uri, album_type='album')
albums = results['items']
while results['next']:
    results = spotify.next(results)
    albums.extend(results['items'])

for album in albums:
    print(album['name'])
# Out:
# Enter the URL you were redirected to: https://accounts.spotify.com/en/authorize?client_id=c5673060fd044f629bee6b8e45c5b584&response_type=code&redirect_uri=https%3A%2F%2Flocalhost%3A7777%2Fds3kCallback
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\spotipy\oauth2.py:559, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     551 response = self._session.post(
#     552     self.OAUTH_TOKEN_URL,
#     553     data=payload,
#    (...)
#     557     timeout=self.requests_timeout,
#     558 )
# --> 559 response.raise_for_status()
#     560 token_info = response.json()
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\requests\models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# -> 1021     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: Bad Request for url: https://accounts.spotify.com/api/token
#
# During handling of the above exception, another exception occurred:
#
# SpotifyOauthError                         Traceback (most recent call last)
# Cell In [7], line 8
#       5 birdy_uri = 'spotify:artist:2WX2uTcsvV5OnS0inACecP'
#       6 spotify = spotipy.Spotify(client_credentials_manager=SpotifyOAuth(**env_vars))
# ----> 8 results = spotify.artist_albums(birdy_uri, album_type='album')
#       9 albums = results['items']
#      10 while results['next']:
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\spotipy\client.py:392, in Spotify.artist_albums(self, artist_id, album_type, country, limit, offset)
#     381 """ Get Spotify catalog information about an artist's albums
#     382
#     383     Parameters:
#    (...)
#     388         - offset - the index of the first album to return
#     389 """
#     391 trid = self._get_id("artist", artist_id)
# --> 392 return self._get(
#     393     "artists/" + trid + "/albums",
#     394     album_type=album_type,
#     395     country=country,
#     396     limit=limit,
#     397     offset=offset,
#     398 )
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\spotipy\client.py:297, in Spotify._get(self, url, args, payload, **kwargs)
#     294 if args:
#     295     kwargs.update(args)
# --> 297 return self._internal_call("GET", url, payload, kwargs)
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\spotipy\client.py:221, in Spotify._internal_call(self, method, url, payload, params)
#     219 if not url.startswith("http"):
#     220     url = self.prefix + url
# --> 221 headers = self._auth_headers()
#     223 if "content_type" in args["params"]:
#     224     headers["Content-Type"] = args["params"]["content_type"]
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\spotipy\client.py:212, in Spotify._auth_headers(self)
#     210     return {}
#     211 try:
# --> 212     token = self.auth_manager.get_access_token(as_dict=False)
#     213 except TypeError:
#     214     token = self.auth_manager.get_access_token()
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\spotipy\oauth2.py:565, in SpotifyOAuth.get_access_token(self, code, as_dict, check_cache)
#     563     return token_info if as_dict else token_info["access_token"]
#     564 except requests.exceptions.HTTPError as http_error:
# --> 565     self._handle_oauth_error(http_error)
#
# File C:\School\DS3000 Foundations\Project\ds3k\venv\lib\site-packages\spotipy\oauth2.py:146, in SpotifyAuthBase._handle_oauth_error(self, http_error)
#     143     error = response.txt or None
#     144     error_description = None
# --> 146 raise SpotifyOauthError(
#     147     'error: {0}, error_description: {1}'.format(
#     148         error, error_description
#     149     ),
#     150     error=error,
#     151     error_description=error_description
#     152 )
#
# SpotifyOauthError: error: invalid_request, error_description: code must be supplied
