# %%
#imports
import sys
import pandas as pd
import pathlib
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import spotipy.util as util
import pprint
import json
import api_setup

# %%
CWD = pathlib.Path.cwd()
REPO_ROOT = CWD.parent.parent.parent
DATA_DIR = REPO_ROOT / "data"
APP = 'spotify'
NAME = 'nick'
SUBDIRS = 'my_spotify_data/MyData/'
USER_DATA_DIR = DATA_DIR / APP / NAME / SUBDIRS

# API Keys
sys.path.append(REPO_ROOT)
from api_setup import parse_api_kvs
# Understanding the spotipy API and making sure it's installed correctly
env_vars = api_setup.parse_api_kvs(REPO_ROOT / "api-keys")
spotify = spotipy.Spotify(client_credentials_manager=SpotifyOAuth(**env_vars))

# %%
def addFeatures(uri):
    audioFeatures = spotify.audio_features(uri)
    audioFeatures = pd.DataFrame(audioFeatures)
    return audioFeatures.iloc[0]

# %%
def combineMasterFeatures(masterTable):
    master = pd.read_csv(masterTable)
    master = master.head(10) #remove this line later
    master = master.drop(['Unnamed: 0'], axis = 1) #drop extra index
    master['uri'] = master['uri'].str.replace('spotify:track:','')
    audioFeaturesDF = pd.DataFrame()
    masterFeatures = pd.concat([master, master.apply(lambda x: addFeatures(x['uri']), axis = 1)], axis = 1)
    return masterFeatures.head(10)

# %%
combineMasterFeatures('masterTable.csv')
# Out:
#                artist                                              track  \
# 0          LOONA/yyxy                            love4eva (feat. Grimes)
# 1         Danny Brown                                 Side B [Dope Song]
# 2               Latto                           Muwop (feat. Gucci Mane)
# 3           MIMIDEATH                                            abusive
# 4          Rico Nasty                                        Pressing Me
# 5              DaBaby                                              VIBEZ
# 6      Otoboke Beaver                  Leave me alone! No, stay with me!
# 7           Flo Milli                                    Like That Bitch
# 8  Tyler, The Creator  PartyIsntOver/Campfire/Bimmer (feat. Frank Oce...
# 9               Lorde                                     Buzzcut Season
#
#                       uri nick_history jojo_history rich_history  \
# 0  4rKEmhNA19JezqVsSQS4yo          NaN         True          NaN
# 1  26dfLcCVJUdscPvmUmkuSI          NaN         True          NaN
# 2  231WYcXWUxYSx79tuPtzBk          NaN         True          NaN
# 3  11V7vRMorD73js8sfgBOS7          NaN         True          NaN
# 4  3wtVRcrYtWJVs0rBTabJJ8          NaN         True          NaN
# 5  0fySG6A6qLE8IvDpayb5bM         True         True          NaN
# 6  0al4YLXuKajNIiJ1IXi9JL          NaN         True          NaN
# 7  7zoZd2MuTaQEdF1rlq6Vv1          NaN         True          NaN
# 8  04QTBqa3IA4ZAKEuqRPzEH          NaN         True          NaN
# 9  51QEyJI5M7uyd8DOh9tqQY          NaN         True          NaN
#
#    danceability  energy  key  loudness  ...  liveness  valence    tempo  \
# 0         0.738   0.954    1    -2.146  ...     0.222    0.742  102.015
# 1         0.690   0.600    8    -7.331  ...     0.694    0.761  160.080
# 2         0.790   0.614    9    -6.958  ...     0.239    0.630  145.907
# 3         0.828   0.764    2    -7.361  ...     0.237    0.289  110.987
# 4         0.936   0.523    1    -6.390  ...     0.105    0.278  130.014
# 5         0.768   0.652    1    -2.708  ...     0.107    0.777  154.187
# 6         0.321   0.973    9    -1.191  ...     0.086    0.574  132.201
# 7         0.782   0.844   10    -4.142  ...     0.295    0.760   77.435
# 8         0.443   0.576    1    -8.695  ...     0.410    0.127  151.835
# 9         0.733   0.620    1   -10.525  ...     0.117    0.247  111.039
#
#              type                      id  \
# 0  audio_features  4rKEmhNA19JezqVsSQS4yo
# 1  audio_features  26dfLcCVJUdscPvmUmkuSI
# 2  audio_features  231WYcXWUxYSx79tuPtzBk
# 3  audio_features  11V7vRMorD73js8sfgBOS7
# 4  audio_features  3wtVRcrYtWJVs0rBTabJJ8
# 5  audio_features  0fySG6A6qLE8IvDpayb5bM
# 6  audio_features  0al4YLXuKajNIiJ1IXi9JL
# 7  audio_features  7zoZd2MuTaQEdF1rlq6Vv1
# 8  audio_features  04QTBqa3IA4ZAKEuqRPzEH
# 9  audio_features  51QEyJI5M7uyd8DOh9tqQY
#
#                                     uri  \
# 0  spotify:track:4rKEmhNA19JezqVsSQS4yo
# 1  spotify:track:26dfLcCVJUdscPvmUmkuSI
# 2  spotify:track:231WYcXWUxYSx79tuPtzBk
# 3  spotify:track:11V7vRMorD73js8sfgBOS7
# 4  spotify:track:3wtVRcrYtWJVs0rBTabJJ8
# 5  spotify:track:0fySG6A6qLE8IvDpayb5bM
# 6  spotify:track:0al4YLXuKajNIiJ1IXi9JL
# 7  spotify:track:7zoZd2MuTaQEdF1rlq6Vv1
# 8  spotify:track:04QTBqa3IA4ZAKEuqRPzEH
# 9  spotify:track:51QEyJI5M7uyd8DOh9tqQY
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4rKEmhNA19Je...
# 1  https://api.spotify.com/v1/tracks/26dfLcCVJUds...
# 2  https://api.spotify.com/v1/tracks/231WYcXWUxYS...
# 3  https://api.spotify.com/v1/tracks/11V7vRMorD73...
# 4  https://api.spotify.com/v1/tracks/3wtVRcrYtWJV...
# 5  https://api.spotify.com/v1/tracks/0fySG6A6qLE8...
# 6  https://api.spotify.com/v1/tracks/0al4YLXuKajN...
# 7  https://api.spotify.com/v1/tracks/7zoZd2MuTaQE...
# 8  https://api.spotify.com/v1/tracks/04QTBqa3IA4Z...
# 9  https://api.spotify.com/v1/tracks/51QEyJI5M7uy...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4rKE...      220477
# 1  https://api.spotify.com/v1/audio-analysis/26df...      156744
# 2  https://api.spotify.com/v1/audio-analysis/231W...      200135
# 3  https://api.spotify.com/v1/audio-analysis/11V7...       72801
# 4  https://api.spotify.com/v1/audio-analysis/3wtV...      162636
# 5  https://api.spotify.com/v1/audio-analysis/0fyS...      144935
# 6  https://api.spotify.com/v1/audio-analysis/0al4...      101840
# 7  https://api.spotify.com/v1/audio-analysis/7zoZ...      203044
# 8  https://api.spotify.com/v1/audio-analysis/04QT...      438493
# 9  https://api.spotify.com/v1/audio-analysis/51QE...      246755
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
# 5              4
# 6              4
# 7              4
# 8              4
# 9              4
#
# [10 rows x 24 columns]

# %%
addFeatures('4rKEmhNA19JezqVsSQS4yo')
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.738   0.954    1    -2.146     1       0.0356        0.0692
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0                 0     0.222    0.742  102.015  audio_features
#
#                        id                                   uri  \
# 0  4rKEmhNA19JezqVsSQS4yo  spotify:track:4rKEmhNA19JezqVsSQS4yo
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/4rKEmhNA19Je...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/4rKE...       220477
#
#    time_signature
# 0               4
